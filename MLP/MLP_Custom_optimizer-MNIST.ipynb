# %%
import os
import numpy as np
import time
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
from keras.datasets import mnist

# load and normalize data
(X_train, y_train), (X_test, y_test) =  tf.keras.datasets.mnist.load_data()
#(X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()


X_train = tf.reshape(X_train, (X_train.shape[0],-1))/255
X_test = tf.reshape(X_test, (X_test.shape[0],-1))/255

#reserve the last 10000 training examples for validation
X_train, X_val = X_train[:-10000], X_train[-10000:]
y_train, y_val = y_train[:-10000], y_train[-10000:]

print("train_size:", X_train.shape)
print("val_size:", X_val.shape)
print("test_size:", X_test.shape)
print("train_output_size", y_train.shape)
print("val_output_size:", y_val.shape)
print("test_output_size", y_test.shape)

size_input = X_train.shape[1]
size_output = len(set(y_train))
size_hidden1 = 256
size_hidden2 = 128
# Out:
# train_size: (50000, 784)
# val_size: (10000, 784)
# test_size: (10000, 784)
# train_output_size (50000,)
# val_output_size: (10000,)
# test_output_size (10000,)

# %%
# Define class to build mlp model
class MLP(object):
    def __init__(self, size_input, size_hidden1, size_hidden2, size_output, device=None,\
                 regularizer=None, R_lambda = 1e-4, drop_prob=0):
        """
        size_input: int, size of input layer
        size_hidden: int, size of hidden layer
        size_output: int, size of output layer
        device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
        regularizer: str or None
        R_lambda: the parameter for regularizer
        drop_prob: 0 to 1
        """
        self.size_input, self.size_hidden1, self.size_hidden2, self.size_output, self.device =\
        size_input, size_hidden1, size_hidden2, size_output, device
        
        self.regularizer, self.R_lambda, self.drop_prob = regularizer, R_lambda, drop_prob
        
        # Initialize weights between input layer and hidden layer 1
        self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
        # Initialize biases for hidden layer 1
        self.b1 = tf.Variable(tf.random.normal([1, self.size_hidden1]))# 0 or constant(0.01)

        # Initialize weights between hidden layer 1 and hidden layer 2
        self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
        # Initialize biases for hidden layer 2
        self.b2 = tf.Variable(tf.random.normal([1, self.size_hidden2]))

         # Initialize weights between hidden layer 2 and output layer
        self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_output],stddev=0.1))
        # Initialize biases for output layer
        self.b3 = tf.Variable(tf.random.normal([1, self.size_output]))

        # Define variables to be updated during backpropagation
        self.variables = [self.W1, self.W2, self.W3, self.b1, self.b2, self.b3]
        
        # Initialize the state of custom optimizer
        #note that this is for custom optimizer but not for the variables, therefore they are just zeros. 
        self.v_W1 = tf.Variable(tf.zeros([self.size_input, self.size_hidden1]))
        self.v_b1 = tf.Variable(tf.zeros([1,self.size_hidden1]))
        self.u_W1 = tf.Variable(tf.zeros([self.size_input, self.size_hidden1]))
        self.u_b1 = tf.Variable(tf.zeros([1,self.size_hidden1]))
        self.m_W1 = tf.Variable(tf.zeros([self.size_input, self.size_hidden1]))
        self.m_b1 = tf.Variable(tf.zeros([1,self.size_hidden1]))
        
        self.v_W2 = tf.Variable(tf.zeros([self.size_hidden1, self.size_hidden2]))
        self.v_b2 = tf.Variable(tf.zeros([1,self.size_hidden2]))
        self.u_W2 = tf.Variable(tf.zeros([self.size_hidden1, self.size_hidden2]))
        self.u_b2 = tf.Variable(tf.zeros([1,self.size_hidden2]))
        self.m_W2 = tf.Variable(tf.zeros([self.size_hidden1, self.size_hidden2]))
        self.m_b2 = tf.Variable(tf.zeros([1,self.size_hidden2]))
        
        self.v_W3 = tf.Variable(tf.zeros([self.size_hidden2, self.size_output]))
        self.v_b3 = tf.Variable(tf.zeros([1,self.size_output]))
        self.u_W3 = tf.Variable(tf.zeros([self.size_hidden2, self.size_output]))
        self.u_b3 = tf.Variable(tf.zeros([1,self.size_output]))
        self.m_W3 = tf.Variable(tf.zeros([self.size_hidden2, self.size_output]))
        self.m_b3 = tf.Variable(tf.zeros([1,self.size_output]))
        
        self.v_state = [self.v_W1,self.v_W2,self.v_W3,self.v_b1,self.v_b2,self.v_b3]
        self.u_state = [self.u_W1,self.u_W2,self.u_W3,self.u_b1,self.u_b2,self.u_b3]
        self.m_state = [self.m_W1,self.m_W2,self.m_W3,self.m_b1,self.m_b2,self.m_b3]
       
    def forward(self, X):
        """
        forward pass
        X: Tensor, inputs
        """
        def compute_output(X):
            # Cast X to float32
            X_tf = tf.cast(X, dtype=tf.float32)
            
            #set the dropout prob
            prob = self.drop_prob

            # Remember to normalize your dataset before moving forward
            # Compute values in hidden layer 1
            what1 = tf.matmul(X_tf, self.W1) + self.b1
            hhat1 = tf.nn.experimental.stateless_dropout(tf.nn.relu(what1), rate = prob, seed = [1,0])/(1-prob)

            # Compute values in hidden layer 2
            what2 = tf.matmul(hhat1, self.W2) + self.b2
            hhat2 = tf.nn.experimental.stateless_dropout(tf.nn.relu(what2), rate = prob, seed = [1,0])/(1-prob)
#             print('layer-relu')
#             print(hhat2[:10])

            # Compute output
            output = tf.nn.softmax(tf.matmul(hhat2, self.W3) + self.b3)
#             print('output')
#             print(output[:10])

            return output
        
        if self.device is not None:
            with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
                self.y = compute_output(X)
        else:
            self.y = compute_output(X)

        return self.y
    
    def loss(self, y_pred, y_true):
        '''
        y_pred - Tensor of shape (batch_size, size_output)
        y_true - Tensor of shape (batch_size, size_output)
        '''  
        #cross entropy loss for classifation mission
        return tf.losses.sparse_categorical_crossentropy(y_true,y_pred, from_logits = False)
        #return tf.reduce_sum(-tf.math.log(tf.boolean_mask(y_pred, tf.one_hot(y_true, depth=y_pred.shape[-1]))))/y_pred.shape[0]
        
    def backward(self, X_train, y_train, hyperparams, method='custom'):
        """
        backward pass
        """
        with tf.GradientTape() as tape:
            predicted = self.forward(X_train)
            current_loss = self.loss(predicted, y_train)
            
            num_layer = 3
            if not self.regularizer:
                current_loss = self.loss(predicted, y_train)
            elif self.regularizer == 'l2':
                #flatten shape
                w = tf.concat([tf.reshape(w,[-1]) for w in self.variables[:num_layer]],0)
                current_loss  += self.R_lambda * tf.nn.l2_loss(w)
            elif self.regularizer == 'l1':
                #flatten shape
                w = tf.concat([tf.reshape(w,[-1]) for w in self.variables[:num_layer]],0)
                current_loss  += self.R_lambda * tf.nn.l1_loss(w)
            
        grads = tape.gradient(current_loss, self.variables)
        
        if method == 'sgd':
            optimizer = tf.keras.optimizers.SGD(learning_rate = hyperparams['lr'])
            optimizer.apply_gradients(zip(grads, self.variables))
        elif method == 'adam':
            optimizer = tf.keras.optimizers.Adam(learning_rate=hyperparams['lr'], beta_1=0.9, beta_2=0.999, epsilon=1e-6,amsgrad=False,name='Adam')
            optimizer.apply_gradients(zip(grads, self.variables))
        elif method == 'custom':
            #Custom optimizer
            beta1,beta2,beta3,eps = 0.9,0.999,0.999987,1e-8

            for p,m,v,u,grad in zip(self.variables, self.m_state, self.v_state, self.u_state, grads):
                m[:].assign(beta1 * m  + (1 - beta1) * grad)
                v[:].assign(beta2 * v  + (1 - beta2) * tf.math.square(grad))
                u[:].assign(beta3 * u  + (1 - beta3) * tf.math.pow(grad, 3))
                m_bias_corr = m / (1 - beta1 ** hyperparams['t'])
                v_bias_corr = v / (1 - beta1 ** hyperparams['t'])
                u_bias_corr = u / (1 - beta2 ** hyperparams['t'])
                p[:].assign(p - hyperparams['lr'] * m_bias_corr/ (tf.math.sqrt(v_bias_corr) + eps*tf.math.sign(u_bias_corr)*tf.math.pow(abs(u_bias_corr),1.0/3.0) + eps))


    def accuracy(self,y_pred, y_true):
        """
        compute the correct num
        y_pred: the probability distribution [[...]] or the predicted label [...]
        y_true: the 1-D true label
        """
        #detect if y_pred is a probability distribution 
        if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
            y_pred = tf.argmax(y_pred, axis=1)
            
        cmp = tf.cast(y_pred, y_true.dtype) == y_true
        
        return float(tf.reduce_sum(tf.cast(cmp, tf.int32)))
    
#     def dropout_layer(self,X, dropout):
#         assert 0 <= dropout <= 1
#         # In this case, all elements are dropped out
#         if dropout == 1:
#             return tf.zeros_like(X)
#         # In this case, all elements are kept
#         if dropout == 0:
#             return X
#         mask = tf.random.uniform(
#             shape=tf.shape(X), minval=0, maxval=1) < 1 - dropout
#         return tf.cast(mask, dtype=tf.float32) * X / (1.0 - dropout)

# %% [markdown]
# # Train Model with Custom Opitmizer

# %%
#save the model for tuning
import pickle
def save_object(obj, filename):
    # Overwrites any existing file.
    with open(filename, 'wb') as file:  
        pickle.dump(obj, file, pickle.HIGHEST_PROTOCOL)
        
def load_object(filename):
    # Open the file in binary mode
    with open(filename, 'rb') as file:  
        # Call load method to deserialze
        return pickle.load(file)

# Set number of simulations and epochs
NUM_SIM = 10
NUM_EPOCHS = 50

#set the train_record
train_loss_record = [[] for _ in range(NUM_SIM)]
train_acc_record = [[] for _ in range(NUM_SIM)]
val_loss_record = [[] for _ in range(NUM_SIM)]
val_acc_record = [[] for _ in range(NUM_SIM)]
test_loss_record = [[] for _ in range(NUM_SIM)]
test_acc_record = [[] for _ in range(NUM_SIM)]

for num_sim in range(NUM_SIM):
    np.random.seed(num_sim)
    tf.random.set_seed(num_sim)
    '''
    Initialize model using GPU or load an exitsing MLP
    '''
    mlp_DIY = MLP(size_input, size_hidden1, size_hidden2, size_output, device='GPU',\
                 regularizer='l2', R_lambda = 1e-4, drop_prob=0.)
    #mlp_DIY = load_object('mlp_DIY.pkl')

    time_start = time.time()
    hyperparams = {'t':1, 'lr':2e-5}

    for epoch in range(NUM_EPOCHS):
        train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*num_sim).batch(128)

        for inputs, outputs in train_ds:
            preds = mlp_DIY.forward(inputs)

            #use custom optimizer to train the model
            mlp_DIY.backward(inputs, outputs, hyperparams,'custom')
            hyperparams['t'] += 1
        
        if (epoch + 1)%5 == 0:
            #compute the result for the current epoch
            logits = mlp_DIY.forward(X_train)
            train_loss = np.sum(mlp_DIY.loss(logits, y_train))/len(y_train)
            train_acc = mlp_DIY.accuracy(logits,y_train)/len(y_train)
            train_loss_record[num_sim].append(train_loss)
            train_acc_record[num_sim].append(train_acc)

            logits = mlp_DIY.forward(X_val)
            val_loss = np.sum(mlp_DIY.loss(logits, y_val))/len(y_val)
            val_acc = mlp_DIY.accuracy(logits,y_val)/len(y_val)
            val_loss_record[num_sim].append(val_loss)
            val_acc_record[num_sim].append(val_acc)
            
            logits = mlp_DIY.forward(X_test)
            test_loss = np.sum(mlp_DIY.loss(logits, y_test))/len(y_test)
            test_acc = mlp_DIY.accuracy(logits,y_test)/len(y_test)
            test_loss_record[num_sim].append(test_loss)
            test_acc_record[num_sim].append(test_acc)
            
            print('Number of Simulation = {} - Number of Epoch = {}'.format(num_sim+1, epoch + 1))
            print('Train loss:= {:.4f} - Val loss: {:.4f} - Test loss: {:.4f} - Train acc:= {:.2%} - Val acc:= {:.2%} - Test acc:= {:.2%}'\
                  .format(train_loss, val_loss, test_loss, train_acc, val_acc, test_acc))
            
    time_taken = time.time() - time_start 
    print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#save_object(mlp_DIY,'mlp_DIY_dropout.pkl')
# Out:
# Number of Simulation = 1 - Number of Epoch = 5
# Train loss:= 0.3357 - Val loss: 0.3106 - Test loss: 0.3197 - Train acc:= 90.84% - Val acc:= 91.46% - Test acc:= 91.47%
# Number of Simulation = 1 - Number of Epoch = 10
# Train loss:= 0.2615 - Val loss: 0.2455 - Test loss: 0.2554 - Train acc:= 92.69% - Val acc:= 93.30% - Test acc:= 93.00%
# Number of Simulation = 1 - Number of Epoch = 15
# Train loss:= 0.2224 - Val loss: 0.2119 - Test loss: 0.2227 - Train acc:= 93.79% - Val acc:= 94.24% - Test acc:= 93.64%
# Number of Simulation = 1 - Number of Epoch = 20
# Train loss:= 0.1944 - Val loss: 0.1884 - Test loss: 0.1995 - Train acc:= 94.50% - Val acc:= 94.95% - Test acc:= 94.17%
# Number of Simulation = 1 - Number of Epoch = 25
# Train loss:= 0.1728 - Val loss: 0.1709 - Test loss: 0.1817 - Train acc:= 95.14% - Val acc:= 95.50% - Test acc:= 94.58%
# Number of Simulation = 1 - Number of Epoch = 30
# Train loss:= 0.1554 - Val loss: 0.1572 - Test loss: 0.1674 - Train acc:= 95.64% - Val acc:= 95.83% - Test acc:= 95.00%
# Number of Simulation = 1 - Number of Epoch = 35
# Train loss:= 0.1406 - Val loss: 0.1461 - Test loss: 0.1555 - Train acc:= 96.06% - Val acc:= 96.13% - Test acc:= 95.47%
# Number of Simulation = 1 - Number of Epoch = 40
# Train loss:= 0.1280 - Val loss: 0.1370 - Test loss: 0.1455 - Train acc:= 96.44% - Val acc:= 96.30% - Test acc:= 95.79%
# Number of Simulation = 1 - Number of Epoch = 45
# Train loss:= 0.1170 - Val loss: 0.1293 - Test loss: 0.1370 - Train acc:= 96.77% - Val acc:= 96.50% - Test acc:= 95.98%
# Number of Simulation = 1 - Number of Epoch = 50
# Train loss:= 0.1074 - Val loss: 0.1227 - Test loss: 0.1297 - Train acc:= 97.07% - Val acc:= 96.67% - Test acc:= 96.11%
#
# Total time taken (in seconds): 451.93
# Number of Simulation = 2 - Number of Epoch = 5
# Train loss:= 0.3433 - Val loss: 0.3139 - Test loss: 0.3233 - Train acc:= 90.42% - Val acc:= 91.40% - Test acc:= 91.20%
# Number of Simulation = 2 - Number of Epoch = 10
# Train loss:= 0.2658 - Val loss: 0.2474 - Test loss: 0.2549 - Train acc:= 92.51% - Val acc:= 93.15% - Test acc:= 92.85%
# Number of Simulation = 2 - Number of Epoch = 15
# Train loss:= 0.2246 - Val loss: 0.2132 - Test loss: 0.2201 - Train acc:= 93.66% - Val acc:= 94.24% - Test acc:= 93.84%
# Number of Simulation = 2 - Number of Epoch = 20
# Train loss:= 0.1958 - Val loss: 0.1895 - Test loss: 0.1958 - Train acc:= 94.50% - Val acc:= 94.93% - Test acc:= 94.56%
# Number of Simulation = 2 - Number of Epoch = 25
# Train loss:= 0.1738 - Val loss: 0.1719 - Test loss: 0.1777 - Train acc:= 95.15% - Val acc:= 95.36% - Test acc:= 94.95%
# Number of Simulation = 2 - Number of Epoch = 30
# Train loss:= 0.1559 - Val loss: 0.1580 - Test loss: 0.1635 - Train acc:= 95.70% - Val acc:= 95.76% - Test acc:= 95.22%
# Number of Simulation = 2 - Number of Epoch = 35
# Train loss:= 0.1410 - Val loss: 0.1467 - Test loss: 0.1517 - Train acc:= 96.09% - Val acc:= 96.02% - Test acc:= 95.54%
# Number of Simulation = 2 - Number of Epoch = 40
# Train loss:= 0.1282 - Val loss: 0.1373 - Test loss: 0.1416 - Train acc:= 96.43% - Val acc:= 96.11% - Test acc:= 95.82%
# Number of Simulation = 2 - Number of Epoch = 45
# Train loss:= 0.1173 - Val loss: 0.1295 - Test loss: 0.1330 - Train acc:= 96.77% - Val acc:= 96.40% - Test acc:= 96.00%
# Number of Simulation = 2 - Number of Epoch = 50
# Train loss:= 0.1076 - Val loss: 0.1229 - Test loss: 0.1256 - Train acc:= 97.08% - Val acc:= 96.54% - Test acc:= 96.16%
#
# Total time taken (in seconds): 559.75
# Number of Simulation = 3 - Number of Epoch = 5
# Train loss:= 0.3438 - Val loss: 0.3188 - Test loss: 0.3256 - Train acc:= 90.56% - Val acc:= 91.42% - Test acc:= 90.94%
# Number of Simulation = 3 - Number of Epoch = 10
# Train loss:= 0.2651 - Val loss: 0.2493 - Test loss: 0.2537 - Train acc:= 92.53% - Val acc:= 92.89% - Test acc:= 92.88%
# Number of Simulation = 3 - Number of Epoch = 15
# Train loss:= 0.2245 - Val loss: 0.2144 - Test loss: 0.2181 - Train acc:= 93.67% - Val acc:= 94.06% - Test acc:= 93.77%
# Number of Simulation = 3 - Number of Epoch = 20
# Train loss:= 0.1965 - Val loss: 0.1910 - Test loss: 0.1944 - Train acc:= 94.45% - Val acc:= 94.79% - Test acc:= 94.40%
# Number of Simulation = 3 - Number of Epoch = 25
# Train loss:= 0.1749 - Val loss: 0.1736 - Test loss: 0.1764 - Train acc:= 95.05% - Val acc:= 95.34% - Test acc:= 94.90%
# Number of Simulation = 3 - Number of Epoch = 30
# Train loss:= 0.1574 - Val loss: 0.1601 - Test loss: 0.1620 - Train acc:= 95.58% - Val acc:= 95.71% - Test acc:= 95.39%
# Number of Simulation = 3 - Number of Epoch = 35
# Train loss:= 0.1428 - Val loss: 0.1492 - Test loss: 0.1503 - Train acc:= 96.03% - Val acc:= 96.06% - Test acc:= 95.72%
# Number of Simulation = 3 - Number of Epoch = 40
# Train loss:= 0.1303 - Val loss: 0.1402 - Test loss: 0.1405 - Train acc:= 96.40% - Val acc:= 96.28% - Test acc:= 95.97%
# Number of Simulation = 3 - Number of Epoch = 45
# Train loss:= 0.1196 - Val loss: 0.1327 - Test loss: 0.1323 - Train acc:= 96.72% - Val acc:= 96.42% - Test acc:= 96.12%
# Number of Simulation = 3 - Number of Epoch = 50
# Train loss:= 0.1102 - Val loss: 0.1263 - Test loss: 0.1255 - Train acc:= 97.01% - Val acc:= 96.60% - Test acc:= 96.30%
#
# Total time taken (in seconds): 575.57
# Number of Simulation = 4 - Number of Epoch = 5
# Train loss:= 0.3302 - Val loss: 0.3051 - Test loss: 0.3190 - Train acc:= 90.81% - Val acc:= 91.73% - Test acc:= 91.15%
# Number of Simulation = 4 - Number of Epoch = 10
# Train loss:= 0.2573 - Val loss: 0.2438 - Test loss: 0.2558 - Train acc:= 92.83% - Val acc:= 93.23% - Test acc:= 92.79%
# Number of Simulation = 4 - Number of Epoch = 15
# Train loss:= 0.2178 - Val loss: 0.2115 - Test loss: 0.2225 - Train acc:= 93.92% - Val acc:= 94.17% - Test acc:= 93.69%
# Number of Simulation = 4 - Number of Epoch = 20
# Train loss:= 0.1898 - Val loss: 0.1888 - Test loss: 0.1987 - Train acc:= 94.73% - Val acc:= 94.84% - Test acc:= 94.23%
# Number of Simulation = 4 - Number of Epoch = 25
# Train loss:= 0.1679 - Val loss: 0.1714 - Test loss: 0.1801 - Train acc:= 95.27% - Val acc:= 95.31% - Test acc:= 94.83%
# Number of Simulation = 4 - Number of Epoch = 30
# Train loss:= 0.1501 - Val loss: 0.1576 - Test loss: 0.1652 - Train acc:= 95.83% - Val acc:= 95.69% - Test acc:= 95.32%
# Number of Simulation = 4 - Number of Epoch = 35
# Train loss:= 0.1350 - Val loss: 0.1463 - Test loss: 0.1529 - Train acc:= 96.29% - Val acc:= 96.00% - Test acc:= 95.62%
# Number of Simulation = 4 - Number of Epoch = 40
# Train loss:= 0.1224 - Val loss: 0.1370 - Test loss: 0.1429 - Train acc:= 96.65% - Val acc:= 96.18% - Test acc:= 95.89%
# Number of Simulation = 4 - Number of Epoch = 45
# Train loss:= 0.1118 - Val loss: 0.1294 - Test loss: 0.1344 - Train acc:= 96.98% - Val acc:= 96.43% - Test acc:= 96.20%
# Number of Simulation = 4 - Number of Epoch = 50
# Train loss:= 0.1025 - Val loss: 0.1227 - Test loss: 0.1272 - Train acc:= 97.24% - Val acc:= 96.52% - Test acc:= 96.40%
#
# Total time taken (in seconds): 558.45
# Number of Simulation = 5 - Number of Epoch = 5
# Train loss:= 0.3301 - Val loss: 0.3011 - Test loss: 0.3155 - Train acc:= 90.81% - Val acc:= 91.94% - Test acc:= 91.36%
# Number of Simulation = 5 - Number of Epoch = 10
# Train loss:= 0.2565 - Val loss: 0.2396 - Test loss: 0.2508 - Train acc:= 92.70% - Val acc:= 93.18% - Test acc:= 92.98%
# Number of Simulation = 5 - Number of Epoch = 15
# Train loss:= 0.2172 - Val loss: 0.2072 - Test loss: 0.2176 - Train acc:= 93.77% - Val acc:= 94.29% - Test acc:= 93.78%
# Number of Simulation = 5 - Number of Epoch = 20
# Train loss:= 0.1895 - Val loss: 0.1851 - Test loss: 0.1945 - Train acc:= 94.60% - Val acc:= 94.95% - Test acc:= 94.64%
# Number of Simulation = 5 - Number of Epoch = 25
# Train loss:= 0.1681 - Val loss: 0.1682 - Test loss: 0.1770 - Train acc:= 95.33% - Val acc:= 95.43% - Test acc:= 94.88%
# Number of Simulation = 5 - Number of Epoch = 30
# Train loss:= 0.1508 - Val loss: 0.1548 - Test loss: 0.1628 - Train acc:= 95.79% - Val acc:= 95.72% - Test acc:= 95.32%
# Number of Simulation = 5 - Number of Epoch = 35
# Train loss:= 0.1363 - Val loss: 0.1439 - Test loss: 0.1511 - Train acc:= 96.21% - Val acc:= 96.03% - Test acc:= 95.63%
# Number of Simulation = 5 - Number of Epoch = 40
# Train loss:= 0.1240 - Val loss: 0.1349 - Test loss: 0.1412 - Train acc:= 96.56% - Val acc:= 96.25% - Test acc:= 95.80%
# Number of Simulation = 5 - Number of Epoch = 45
# Train loss:= 0.1133 - Val loss: 0.1275 - Test loss: 0.1328 - Train acc:= 96.88% - Val acc:= 96.45% - Test acc:= 95.98%
# Number of Simulation = 5 - Number of Epoch = 50
# Train loss:= 0.1040 - Val loss: 0.1210 - Test loss: 0.1256 - Train acc:= 97.14% - Val acc:= 96.65% - Test acc:= 96.17%
#
# Total time taken (in seconds): 595.19
# Number of Simulation = 6 - Number of Epoch = 5
# Train loss:= 0.3212 - Val loss: 0.2982 - Test loss: 0.3049 - Train acc:= 91.21% - Val acc:= 91.87% - Test acc:= 91.72%
# Number of Simulation = 6 - Number of Epoch = 10
# Train loss:= 0.2498 - Val loss: 0.2353 - Test loss: 0.2431 - Train acc:= 93.09% - Val acc:= 93.52% - Test acc:= 93.23%
# Number of Simulation = 6 - Number of Epoch = 15
# Train loss:= 0.2110 - Val loss: 0.2021 - Test loss: 0.2103 - Train acc:= 94.12% - Val acc:= 94.55% - Test acc:= 94.08%
# Number of Simulation = 6 - Number of Epoch = 20
# Train loss:= 0.1841 - Val loss: 0.1802 - Test loss: 0.1877 - Train acc:= 94.84% - Val acc:= 95.16% - Test acc:= 94.68%
# Number of Simulation = 6 - Number of Epoch = 25
# Train loss:= 0.1633 - Val loss: 0.1641 - Test loss: 0.1705 - Train acc:= 95.42% - Val acc:= 95.62% - Test acc:= 95.03%
# Number of Simulation = 6 - Number of Epoch = 30
# Train loss:= 0.1466 - Val loss: 0.1517 - Test loss: 0.1569 - Train acc:= 95.90% - Val acc:= 95.94% - Test acc:= 95.42%
# Number of Simulation = 6 - Number of Epoch = 35
# Train loss:= 0.1326 - Val loss: 0.1416 - Test loss: 0.1458 - Train acc:= 96.35% - Val acc:= 96.27% - Test acc:= 95.71%
# Number of Simulation = 6 - Number of Epoch = 40
# Train loss:= 0.1207 - Val loss: 0.1335 - Test loss: 0.1366 - Train acc:= 96.66% - Val acc:= 96.50% - Test acc:= 95.87%
# Number of Simulation = 6 - Number of Epoch = 45
# Train loss:= 0.1105 - Val loss: 0.1265 - Test loss: 0.1288 - Train acc:= 96.98% - Val acc:= 96.73% - Test acc:= 95.94%
# Number of Simulation = 6 - Number of Epoch = 50
# Train loss:= 0.1015 - Val loss: 0.1207 - Test loss: 0.1221 - Train acc:= 97.23% - Val acc:= 96.87% - Test acc:= 96.16%
#
# Total time taken (in seconds): 600.93
# Number of Simulation = 7 - Number of Epoch = 5
# Train loss:= 0.3277 - Val loss: 0.3010 - Test loss: 0.3130 - Train acc:= 90.99% - Val acc:= 91.83% - Test acc:= 91.37%
# Number of Simulation = 7 - Number of Epoch = 10
# Train loss:= 0.2567 - Val loss: 0.2415 - Test loss: 0.2507 - Train acc:= 92.69% - Val acc:= 93.35% - Test acc:= 93.04%
# Number of Simulation = 7 - Number of Epoch = 15
# Train loss:= 0.2177 - Val loss: 0.2092 - Test loss: 0.2171 - Train acc:= 93.86% - Val acc:= 94.30% - Test acc:= 94.00%
# Number of Simulation = 7 - Number of Epoch = 20
# Train loss:= 0.1899 - Val loss: 0.1866 - Test loss: 0.1930 - Train acc:= 94.63% - Val acc:= 94.93% - Test acc:= 94.47%
# Number of Simulation = 7 - Number of Epoch = 25
# Train loss:= 0.1683 - Val loss: 0.1697 - Test loss: 0.1747 - Train acc:= 95.23% - Val acc:= 95.41% - Test acc:= 94.95%
# Number of Simulation = 7 - Number of Epoch = 30
# Train loss:= 0.1509 - Val loss: 0.1565 - Test loss: 0.1602 - Train acc:= 95.76% - Val acc:= 95.81% - Test acc:= 95.28%
# Number of Simulation = 7 - Number of Epoch = 35
# Train loss:= 0.1363 - Val loss: 0.1459 - Test loss: 0.1482 - Train acc:= 96.21% - Val acc:= 96.11% - Test acc:= 95.57%
# Number of Simulation = 7 - Number of Epoch = 40
# Train loss:= 0.1239 - Val loss: 0.1375 - Test loss: 0.1385 - Train acc:= 96.61% - Val acc:= 96.24% - Test acc:= 95.85%
# Number of Simulation = 7 - Number of Epoch = 45
# Train loss:= 0.1133 - Val loss: 0.1306 - Test loss: 0.1304 - Train acc:= 96.92% - Val acc:= 96.41% - Test acc:= 96.13%
# Number of Simulation = 7 - Number of Epoch = 50
# Train loss:= 0.1040 - Val loss: 0.1246 - Test loss: 0.1236 - Train acc:= 97.19% - Val acc:= 96.54% - Test acc:= 96.36%
#
# Total time taken (in seconds): 571.73
# Number of Simulation = 8 - Number of Epoch = 5
# Train loss:= 0.3277 - Val loss: 0.2990 - Test loss: 0.3110 - Train acc:= 90.82% - Val acc:= 91.75% - Test acc:= 91.28%
# Number of Simulation = 8 - Number of Epoch = 10
# Train loss:= 0.2535 - Val loss: 0.2361 - Test loss: 0.2462 - Train acc:= 92.87% - Val acc:= 93.48% - Test acc:= 93.00%
# Number of Simulation = 8 - Number of Epoch = 15
# Train loss:= 0.2136 - Val loss: 0.2036 - Test loss: 0.2129 - Train acc:= 93.96% - Val acc:= 94.36% - Test acc:= 93.83%
# Number of Simulation = 8 - Number of Epoch = 20
# Train loss:= 0.1858 - Val loss: 0.1816 - Test loss: 0.1897 - Train acc:= 94.76% - Val acc:= 94.99% - Test acc:= 94.41%
# Number of Simulation = 8 - Number of Epoch = 25
# Train loss:= 0.1644 - Val loss: 0.1652 - Test loss: 0.1722 - Train acc:= 95.41% - Val acc:= 95.53% - Test acc:= 94.94%
# Number of Simulation = 8 - Number of Epoch = 30
# Train loss:= 0.1472 - Val loss: 0.1524 - Test loss: 0.1584 - Train acc:= 95.93% - Val acc:= 95.84% - Test acc:= 95.28%
# Number of Simulation = 8 - Number of Epoch = 35
# Train loss:= 0.1329 - Val loss: 0.1421 - Test loss: 0.1472 - Train acc:= 96.28% - Val acc:= 96.03% - Test acc:= 95.59%
# Number of Simulation = 8 - Number of Epoch = 40
# Train loss:= 0.1206 - Val loss: 0.1335 - Test loss: 0.1377 - Train acc:= 96.65% - Val acc:= 96.19% - Test acc:= 95.88%
# Number of Simulation = 8 - Number of Epoch = 45
# Train loss:= 0.1101 - Val loss: 0.1263 - Test loss: 0.1298 - Train acc:= 96.99% - Val acc:= 96.42% - Test acc:= 96.07%
# Number of Simulation = 8 - Number of Epoch = 50
# Train loss:= 0.1008 - Val loss: 0.1202 - Test loss: 0.1230 - Train acc:= 97.28% - Val acc:= 96.56% - Test acc:= 96.25%
#
# Total time taken (in seconds): 566.21
# Number of Simulation = 9 - Number of Epoch = 5
# Train loss:= 0.3314 - Val loss: 0.3041 - Test loss: 0.3169 - Train acc:= 90.66% - Val acc:= 91.55% - Test acc:= 91.23%
# Number of Simulation = 9 - Number of Epoch = 10
# Train loss:= 0.2560 - Val loss: 0.2400 - Test loss: 0.2502 - Train acc:= 92.75% - Val acc:= 93.39% - Test acc:= 92.84%
# Number of Simulation = 9 - Number of Epoch = 15
# Train loss:= 0.2157 - Val loss: 0.2061 - Test loss: 0.2153 - Train acc:= 93.93% - Val acc:= 94.27% - Test acc:= 93.88%
# Number of Simulation = 9 - Number of Epoch = 20
# Train loss:= 0.1876 - Val loss: 0.1829 - Test loss: 0.1914 - Train acc:= 94.69% - Val acc:= 95.01% - Test acc:= 94.54%
# Number of Simulation = 9 - Number of Epoch = 25
# Train loss:= 0.1662 - Val loss: 0.1660 - Test loss: 0.1735 - Train acc:= 95.31% - Val acc:= 95.37% - Test acc:= 94.97%
# Number of Simulation = 9 - Number of Epoch = 30
# Train loss:= 0.1491 - Val loss: 0.1529 - Test loss: 0.1595 - Train acc:= 95.78% - Val acc:= 95.85% - Test acc:= 95.27%
# Number of Simulation = 9 - Number of Epoch = 35
# Train loss:= 0.1349 - Val loss: 0.1425 - Test loss: 0.1482 - Train acc:= 96.21% - Val acc:= 96.20% - Test acc:= 95.61%
# Number of Simulation = 9 - Number of Epoch = 40
# Train loss:= 0.1227 - Val loss: 0.1339 - Test loss: 0.1389 - Train acc:= 96.55% - Val acc:= 96.52% - Test acc:= 95.90%
# Number of Simulation = 9 - Number of Epoch = 45
# Train loss:= 0.1122 - Val loss: 0.1268 - Test loss: 0.1311 - Train acc:= 96.89% - Val acc:= 96.64% - Test acc:= 96.09%
# Number of Simulation = 9 - Number of Epoch = 50
# Train loss:= 0.1029 - Val loss: 0.1207 - Test loss: 0.1245 - Train acc:= 97.14% - Val acc:= 96.76% - Test acc:= 96.29%
#
# Total time taken (in seconds): 570.04
# Number of Simulation = 10 - Number of Epoch = 5
# Train loss:= 0.3324 - Val loss: 0.3063 - Test loss: 0.3165 - Train acc:= 90.73% - Val acc:= 91.45% - Test acc:= 90.97%
# Number of Simulation = 10 - Number of Epoch = 10
# Train loss:= 0.2579 - Val loss: 0.2428 - Test loss: 0.2506 - Train acc:= 92.76% - Val acc:= 93.06% - Test acc:= 92.73%
# Number of Simulation = 10 - Number of Epoch = 15
# Train loss:= 0.2176 - Val loss: 0.2089 - Test loss: 0.2164 - Train acc:= 93.93% - Val acc:= 94.14% - Test acc:= 93.62%
# Number of Simulation = 10 - Number of Epoch = 20
# Train loss:= 0.1893 - Val loss: 0.1853 - Test loss: 0.1929 - Train acc:= 94.72% - Val acc:= 94.89% - Test acc:= 94.25%
# Number of Simulation = 10 - Number of Epoch = 25
# Train loss:= 0.1678 - Val loss: 0.1677 - Test loss: 0.1752 - Train acc:= 95.36% - Val acc:= 95.43% - Test acc:= 94.89%
# Number of Simulation = 10 - Number of Epoch = 30
# Train loss:= 0.1506 - Val loss: 0.1540 - Test loss: 0.1613 - Train acc:= 95.82% - Val acc:= 95.82% - Test acc:= 95.35%
# Number of Simulation = 10 - Number of Epoch = 35
# Train loss:= 0.1363 - Val loss: 0.1430 - Test loss: 0.1503 - Train acc:= 96.25% - Val acc:= 96.05% - Test acc:= 95.67%
# Number of Simulation = 10 - Number of Epoch = 40
# Train loss:= 0.1243 - Val loss: 0.1340 - Test loss: 0.1412 - Train acc:= 96.63% - Val acc:= 96.28% - Test acc:= 95.90%
# Number of Simulation = 10 - Number of Epoch = 45
# Train loss:= 0.1139 - Val loss: 0.1266 - Test loss: 0.1335 - Train acc:= 96.93% - Val acc:= 96.52% - Test acc:= 96.14%
# Number of Simulation = 10 - Number of Epoch = 50
# Train loss:= 0.1048 - Val loss: 0.1203 - Test loss: 0.1270 - Train acc:= 97.21% - Val acc:= 96.62% - Test acc:= 96.26%
#
# Total time taken (in seconds): 559.03

# %%
import matplotlib.pyplot as plt
train_average_loss = np.mean(train_loss_record,0)
train_average_acc = np.mean(train_acc_record,0)
val_average_loss = np.mean(val_loss_record,0)
val_average_acc = np.mean(val_acc_record,0)
test_average_loss = np.mean(test_loss_record,0)
test_average_acc = np.mean(test_acc_record,0)

test_var_acc = np.var(test_acc_record,1)[-1]
x = np.linspace(1,NUM_EPOCHS,len(train_average_loss))

plt.figure()
f, ax = plt.subplots(1,2, sharex = True, sharey = False,figsize=(8,3))
f.suptitle('Report of MLP with l2 for MNIST digits data set')


ax[0].plot(x,train_average_loss,label='train')
ax[0].plot(x,val_average_loss,label='val')
ax[0].plot(x,test_average_loss,label='test')
ax[0].set_yscale('log')
ax[0].set_title('')
ax.flat[0].set(xlabel='Num of epochs', ylabel='Average loss')
ax[0].legend()


ax[1].plot(x,train_average_acc,label='train')
ax[1].plot(x,val_average_acc,label='val')
ax[1].plot(x,test_average_acc,label='test')
ax[1].set_title('')
ax.flat[1].set(xlabel='Num of epochs', ylabel='Average accuray')
ax[1].legend()

print('the final average result: test loss := {:.4f} - test acc := {:.2%} - the std of test acc := {:.4f}'
      .format(test_average_loss[-1], test_average_acc[-1], np.sqrt(test_var_acc)))
f.tight_layout()
plt.show()
# Out:
# the final average result: test loss := 0.1254 - test acc := 96.25% - the std of test acc := 0.0162

# %% [markdown]
# # Train Model with ADAM from keras

# %%
#save the model for tuning
import pickle
def save_object(obj, filename):
    # Overwrites any existing file.
    with open(filename, 'wb') as file:  
        pickle.dump(obj, file, pickle.HIGHEST_PROTOCOL)
        
def load_object(filename):
    # Open the file in binary mode
    with open(filename, 'rb') as file:  
        # Call load method to deserialze
        return pickle.load(file)

# Set number of simulations and epochs
NUM_SIM = 10
NUM_EPOCHS = 50

#set the train_record
train_loss_record = [[] for _ in range(NUM_SIM)]
train_acc_record = [[] for _ in range(NUM_SIM)]
val_loss_record = [[] for _ in range(NUM_SIM)]
val_acc_record = [[] for _ in range(NUM_SIM)]
test_loss_record = [[] for _ in range(NUM_SIM)]
test_acc_record = [[] for _ in range(NUM_SIM)]

for num_sim in range(NUM_SIM):
    np.random.seed(num_sim)
    tf.random.set_seed(num_sim)
    '''
    Initialize model using GPU or load an exitsing MLP
    '''
    mlp_DIY = MLP(size_input, size_hidden1, size_hidden2, size_output, device='GPU',\
                 regularizer='l2', R_lambda = 1e-4, drop_prob=0.)
    #mlp_DIY = load_object('mlp_DIY.pkl')

    time_start = time.time()
    hyperparams = {'t':1, 'lr':2e-5}

    for epoch in range(NUM_EPOCHS):
        train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*num_sim).batch(128)

        for inputs, outputs in train_ds:
            preds = mlp_DIY.forward(inputs)

            #use custom optimizer to train the model
            mlp_DIY.backward(inputs, outputs, hyperparams,'adam')
            hyperparams['t'] += 1
        
        if (epoch + 1)%5 == 0:
            #compute the result for the current epoch
            logits = mlp_DIY.forward(X_train)
            train_loss = np.sum(mlp_DIY.loss(logits, y_train))/len(y_train)
            train_acc = mlp_DIY.accuracy(logits,y_train)/len(y_train)
            train_loss_record[num_sim].append(train_loss)
            train_acc_record[num_sim].append(train_acc)

            logits = mlp_DIY.forward(X_val)
            val_loss = np.sum(mlp_DIY.loss(logits, y_val))/len(y_val)
            val_acc = mlp_DIY.accuracy(logits,y_val)/len(y_val)
            val_loss_record[num_sim].append(val_loss)
            val_acc_record[num_sim].append(val_acc)
            
            logits = mlp_DIY.forward(X_test)
            test_loss = np.sum(mlp_DIY.loss(logits, y_test))/len(y_test)
            test_acc = mlp_DIY.accuracy(logits,y_test)/len(y_test)
            test_loss_record[num_sim].append(test_loss)
            test_acc_record[num_sim].append(test_acc)
            
            print('Number of Simulation = {} - Number of Epoch = {}'.format(num_sim+1, epoch + 1))
            print('Train loss:= {:.4f} - Val loss: {:.4f} - Test loss: {:.4f} - Train acc:= {:.2%} - Val acc:= {:.2%} - Test acc:= {:.2%}'\
                  .format(train_loss, val_loss, test_loss, train_acc, val_acc, test_acc))
            
    time_taken = time.time() - time_start 
    print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#save_object(mlp_DIY,'mlp_DIY_dropout.pkl')
# Out:
# Number of Simulation = 1 - Number of Epoch = 5
# Train loss:= 0.4292 - Val loss: 0.3916 - Test loss: 0.4020 - Train acc:= 88.31% - Val acc:= 89.36% - Test acc:= 89.54%
# Number of Simulation = 1 - Number of Epoch = 10
# Train loss:= 0.3099 - Val loss: 0.2837 - Test loss: 0.2950 - Train acc:= 91.11% - Val acc:= 92.06% - Test acc:= 91.84%
# Number of Simulation = 1 - Number of Epoch = 15
# Train loss:= 0.2666 - Val loss: 0.2467 - Test loss: 0.2582 - Train acc:= 92.30% - Val acc:= 92.99% - Test acc:= 92.75%
# Number of Simulation = 1 - Number of Epoch = 20
# Train loss:= 0.2401 - Val loss: 0.2244 - Test loss: 0.2352 - Train acc:= 93.08% - Val acc:= 93.70% - Test acc:= 93.21%
# Number of Simulation = 1 - Number of Epoch = 25
# Train loss:= 0.2204 - Val loss: 0.2082 - Test loss: 0.2181 - Train acc:= 93.74% - Val acc:= 94.09% - Test acc:= 93.67%
# Number of Simulation = 1 - Number of Epoch = 30
# Train loss:= 0.2045 - Val loss: 0.1953 - Test loss: 0.2044 - Train acc:= 94.14% - Val acc:= 94.41% - Test acc:= 94.02%
# Number of Simulation = 1 - Number of Epoch = 35
# Train loss:= 0.1910 - Val loss: 0.1843 - Test loss: 0.1928 - Train acc:= 94.57% - Val acc:= 94.72% - Test acc:= 94.20%
# Number of Simulation = 1 - Number of Epoch = 40
# Train loss:= 0.1795 - Val loss: 0.1750 - Test loss: 0.1829 - Train acc:= 94.88% - Val acc:= 95.09% - Test acc:= 94.51%
# Number of Simulation = 1 - Number of Epoch = 45
# Train loss:= 0.1694 - Val loss: 0.1671 - Test loss: 0.1743 - Train acc:= 95.13% - Val acc:= 95.34% - Test acc:= 94.86%
# Number of Simulation = 1 - Number of Epoch = 50
# Train loss:= 0.1605 - Val loss: 0.1601 - Test loss: 0.1668 - Train acc:= 95.37% - Val acc:= 95.53% - Test acc:= 95.11%
#
# Total time taken (in seconds): 352.02
# Number of Simulation = 2 - Number of Epoch = 5
# Train loss:= 0.4373 - Val loss: 0.3939 - Test loss: 0.4087 - Train acc:= 87.87% - Val acc:= 89.47% - Test acc:= 89.06%
# Number of Simulation = 2 - Number of Epoch = 10
# Train loss:= 0.3156 - Val loss: 0.2850 - Test loss: 0.2968 - Train acc:= 90.84% - Val acc:= 91.87% - Test acc:= 91.50%
# Number of Simulation = 2 - Number of Epoch = 15
# Train loss:= 0.2693 - Val loss: 0.2456 - Test loss: 0.2559 - Train acc:= 92.23% - Val acc:= 92.95% - Test acc:= 92.48%
# Number of Simulation = 2 - Number of Epoch = 20
# Train loss:= 0.2403 - Val loss: 0.2216 - Test loss: 0.2303 - Train acc:= 93.06% - Val acc:= 93.81% - Test acc:= 93.16%
# Number of Simulation = 2 - Number of Epoch = 25
# Train loss:= 0.2192 - Val loss: 0.2040 - Test loss: 0.2118 - Train acc:= 93.63% - Val acc:= 94.32% - Test acc:= 93.83%
# Number of Simulation = 2 - Number of Epoch = 30
# Train loss:= 0.2025 - Val loss: 0.1904 - Test loss: 0.1970 - Train acc:= 94.07% - Val acc:= 94.65% - Test acc:= 94.41%
# Number of Simulation = 2 - Number of Epoch = 35
# Train loss:= 0.1886 - Val loss: 0.1790 - Test loss: 0.1852 - Train acc:= 94.46% - Val acc:= 95.04% - Test acc:= 94.57%
# Number of Simulation = 2 - Number of Epoch = 40
# Train loss:= 0.1770 - Val loss: 0.1702 - Test loss: 0.1751 - Train acc:= 94.81% - Val acc:= 95.26% - Test acc:= 94.75%
# Number of Simulation = 2 - Number of Epoch = 45
# Train loss:= 0.1667 - Val loss: 0.1620 - Test loss: 0.1661 - Train acc:= 95.08% - Val acc:= 95.46% - Test acc:= 94.98%
# Number of Simulation = 2 - Number of Epoch = 50
# Train loss:= 0.1576 - Val loss: 0.1548 - Test loss: 0.1584 - Train acc:= 95.34% - Val acc:= 95.70% - Test acc:= 95.20%
#
# Total time taken (in seconds): 355.12
# Number of Simulation = 3 - Number of Epoch = 5
# Train loss:= 0.4440 - Val loss: 0.4068 - Test loss: 0.4200 - Train acc:= 87.89% - Val acc:= 89.29% - Test acc:= 88.65%
# Number of Simulation = 3 - Number of Epoch = 10
# Train loss:= 0.3181 - Val loss: 0.2920 - Test loss: 0.2998 - Train acc:= 90.83% - Val acc:= 91.75% - Test acc:= 91.22%
# Number of Simulation = 3 - Number of Epoch = 15
# Train loss:= 0.2719 - Val loss: 0.2518 - Test loss: 0.2577 - Train acc:= 92.11% - Val acc:= 92.59% - Test acc:= 92.45%
# Number of Simulation = 3 - Number of Epoch = 20
# Train loss:= 0.2436 - Val loss: 0.2275 - Test loss: 0.2328 - Train acc:= 92.98% - Val acc:= 93.33% - Test acc:= 93.06%
# Number of Simulation = 3 - Number of Epoch = 25
# Train loss:= 0.2228 - Val loss: 0.2096 - Test loss: 0.2148 - Train acc:= 93.59% - Val acc:= 94.01% - Test acc:= 93.56%
# Number of Simulation = 3 - Number of Epoch = 30
# Train loss:= 0.2063 - Val loss: 0.1958 - Test loss: 0.2005 - Train acc:= 94.01% - Val acc:= 94.46% - Test acc:= 94.05%
# Number of Simulation = 3 - Number of Epoch = 35
# Train loss:= 0.1927 - Val loss: 0.1846 - Test loss: 0.1887 - Train acc:= 94.41% - Val acc:= 94.83% - Test acc:= 94.48%
# Number of Simulation = 3 - Number of Epoch = 40
# Train loss:= 0.1811 - Val loss: 0.1751 - Test loss: 0.1790 - Train acc:= 94.77% - Val acc:= 95.06% - Test acc:= 94.82%
# Number of Simulation = 3 - Number of Epoch = 45
# Train loss:= 0.1711 - Val loss: 0.1671 - Test loss: 0.1706 - Train acc:= 95.04% - Val acc:= 95.40% - Test acc:= 95.14%
# Number of Simulation = 3 - Number of Epoch = 50
# Train loss:= 0.1624 - Val loss: 0.1602 - Test loss: 0.1633 - Train acc:= 95.32% - Val acc:= 95.56% - Test acc:= 95.20%
#
# Total time taken (in seconds): 338.63
# Number of Simulation = 4 - Number of Epoch = 5
# Train loss:= 0.4295 - Val loss: 0.3890 - Test loss: 0.4059 - Train acc:= 87.95% - Val acc:= 89.45% - Test acc:= 88.76%
# Number of Simulation = 4 - Number of Epoch = 10
# Train loss:= 0.3112 - Val loss: 0.2851 - Test loss: 0.2995 - Train acc:= 90.98% - Val acc:= 91.73% - Test acc:= 91.33%
# Number of Simulation = 4 - Number of Epoch = 15
# Train loss:= 0.2671 - Val loss: 0.2490 - Test loss: 0.2613 - Train acc:= 92.30% - Val acc:= 92.70% - Test acc:= 92.41%
# Number of Simulation = 4 - Number of Epoch = 20
# Train loss:= 0.2396 - Val loss: 0.2262 - Test loss: 0.2377 - Train acc:= 93.14% - Val acc:= 93.36% - Test acc:= 93.07%
# Number of Simulation = 4 - Number of Epoch = 25
# Train loss:= 0.2190 - Val loss: 0.2088 - Test loss: 0.2198 - Train acc:= 93.74% - Val acc:= 94.00% - Test acc:= 93.59%
# Number of Simulation = 4 - Number of Epoch = 30
# Train loss:= 0.2023 - Val loss: 0.1949 - Test loss: 0.2047 - Train acc:= 94.22% - Val acc:= 94.42% - Test acc:= 94.01%
# Number of Simulation = 4 - Number of Epoch = 35
# Train loss:= 0.1881 - Val loss: 0.1828 - Test loss: 0.1916 - Train acc:= 94.59% - Val acc:= 94.84% - Test acc:= 94.38%
# Number of Simulation = 4 - Number of Epoch = 40
# Train loss:= 0.1761 - Val loss: 0.1734 - Test loss: 0.1810 - Train acc:= 94.89% - Val acc:= 95.24% - Test acc:= 94.66%
# Number of Simulation = 4 - Number of Epoch = 45
# Train loss:= 0.1655 - Val loss: 0.1650 - Test loss: 0.1719 - Train acc:= 95.21% - Val acc:= 95.58% - Test acc:= 94.90%
# Number of Simulation = 4 - Number of Epoch = 50
# Train loss:= 0.1562 - Val loss: 0.1579 - Test loss: 0.1637 - Train acc:= 95.50% - Val acc:= 95.78% - Test acc:= 95.16%
#
# Total time taken (in seconds): 352.25
# Number of Simulation = 5 - Number of Epoch = 5
# Train loss:= 0.4338 - Val loss: 0.3888 - Test loss: 0.4096 - Train acc:= 88.11% - Val acc:= 89.77% - Test acc:= 89.04%
# Number of Simulation = 5 - Number of Epoch = 10
# Train loss:= 0.3122 - Val loss: 0.2821 - Test loss: 0.2968 - Train acc:= 90.99% - Val acc:= 92.18% - Test acc:= 91.54%
# Number of Simulation = 5 - Number of Epoch = 15
# Train loss:= 0.2670 - Val loss: 0.2445 - Test loss: 0.2572 - Train acc:= 92.22% - Val acc:= 93.01% - Test acc:= 92.63%
# Number of Simulation = 5 - Number of Epoch = 20
# Train loss:= 0.2392 - Val loss: 0.2214 - Test loss: 0.2329 - Train acc:= 93.01% - Val acc:= 93.66% - Test acc:= 93.11%
# Number of Simulation = 5 - Number of Epoch = 25
# Train loss:= 0.2184 - Val loss: 0.2044 - Test loss: 0.2152 - Train acc:= 93.64% - Val acc:= 94.15% - Test acc:= 93.62%
# Number of Simulation = 5 - Number of Epoch = 30
# Train loss:= 0.2018 - Val loss: 0.1909 - Test loss: 0.2008 - Train acc:= 94.13% - Val acc:= 94.66% - Test acc:= 94.13%
# Number of Simulation = 5 - Number of Epoch = 35
# Train loss:= 0.1879 - Val loss: 0.1794 - Test loss: 0.1887 - Train acc:= 94.53% - Val acc:= 95.10% - Test acc:= 94.50%
# Number of Simulation = 5 - Number of Epoch = 40
# Train loss:= 0.1760 - Val loss: 0.1699 - Test loss: 0.1784 - Train acc:= 94.89% - Val acc:= 95.41% - Test acc:= 94.80%
# Number of Simulation = 5 - Number of Epoch = 45
# Train loss:= 0.1656 - Val loss: 0.1615 - Test loss: 0.1691 - Train acc:= 95.20% - Val acc:= 95.66% - Test acc:= 95.06%
# Number of Simulation = 5 - Number of Epoch = 50
# Train loss:= 0.1566 - Val loss: 0.1543 - Test loss: 0.1614 - Train acc:= 95.45% - Val acc:= 95.81% - Test acc:= 95.29%
#
# Total time taken (in seconds): 336.23
# Number of Simulation = 6 - Number of Epoch = 5
# Train loss:= 0.4113 - Val loss: 0.3765 - Test loss: 0.3848 - Train acc:= 88.60% - Val acc:= 89.93% - Test acc:= 89.71%
# Number of Simulation = 6 - Number of Epoch = 10
# Train loss:= 0.3008 - Val loss: 0.2764 - Test loss: 0.2853 - Train acc:= 91.43% - Val acc:= 92.30% - Test acc:= 92.02%
# Number of Simulation = 6 - Number of Epoch = 15
# Train loss:= 0.2585 - Val loss: 0.2393 - Test loss: 0.2485 - Train acc:= 92.65% - Val acc:= 93.13% - Test acc:= 92.92%
# Number of Simulation = 6 - Number of Epoch = 20
# Train loss:= 0.2319 - Val loss: 0.2162 - Test loss: 0.2252 - Train acc:= 93.34% - Val acc:= 93.93% - Test acc:= 93.61%
# Number of Simulation = 6 - Number of Epoch = 25
# Train loss:= 0.2121 - Val loss: 0.1994 - Test loss: 0.2081 - Train acc:= 93.89% - Val acc:= 94.50% - Test acc:= 94.07%
# Number of Simulation = 6 - Number of Epoch = 30
# Train loss:= 0.1962 - Val loss: 0.1863 - Test loss: 0.1940 - Train acc:= 94.39% - Val acc:= 94.82% - Test acc:= 94.38%
# Number of Simulation = 6 - Number of Epoch = 35
# Train loss:= 0.1832 - Val loss: 0.1754 - Test loss: 0.1825 - Train acc:= 94.76% - Val acc:= 95.14% - Test acc:= 94.65%
# Number of Simulation = 6 - Number of Epoch = 40
# Train loss:= 0.1718 - Val loss: 0.1663 - Test loss: 0.1725 - Train acc:= 95.07% - Val acc:= 95.56% - Test acc:= 94.95%
# Number of Simulation = 6 - Number of Epoch = 45
# Train loss:= 0.1622 - Val loss: 0.1587 - Test loss: 0.1640 - Train acc:= 95.31% - Val acc:= 95.78% - Test acc:= 95.12%
# Number of Simulation = 6 - Number of Epoch = 50
# Train loss:= 0.1537 - Val loss: 0.1524 - Test loss: 0.1568 - Train acc:= 95.56% - Val acc:= 95.97% - Test acc:= 95.38%
#
# Total time taken (in seconds): 332.98
# Number of Simulation = 7 - Number of Epoch = 5
# Train loss:= 0.4174 - Val loss: 0.3764 - Test loss: 0.3918 - Train acc:= 88.52% - Val acc:= 89.99% - Test acc:= 89.36%
# Number of Simulation = 7 - Number of Epoch = 10
# Train loss:= 0.3077 - Val loss: 0.2810 - Test loss: 0.2921 - Train acc:= 91.18% - Val acc:= 91.93% - Test acc:= 91.52%
# Number of Simulation = 7 - Number of Epoch = 15
# Train loss:= 0.2662 - Val loss: 0.2465 - Test loss: 0.2558 - Train acc:= 92.26% - Val acc:= 92.83% - Test acc:= 92.55%
# Number of Simulation = 7 - Number of Epoch = 20
# Train loss:= 0.2394 - Val loss: 0.2244 - Test loss: 0.2328 - Train acc:= 92.93% - Val acc:= 93.58% - Test acc:= 93.17%
# Number of Simulation = 7 - Number of Epoch = 25
# Train loss:= 0.2191 - Val loss: 0.2076 - Test loss: 0.2150 - Train acc:= 93.58% - Val acc:= 94.06% - Test acc:= 93.77%
# Number of Simulation = 7 - Number of Epoch = 30
# Train loss:= 0.2027 - Val loss: 0.1940 - Test loss: 0.2007 - Train acc:= 94.05% - Val acc:= 94.54% - Test acc:= 94.15%
# Number of Simulation = 7 - Number of Epoch = 35
# Train loss:= 0.1888 - Val loss: 0.1829 - Test loss: 0.1887 - Train acc:= 94.39% - Val acc:= 94.97% - Test acc:= 94.38%
# Number of Simulation = 7 - Number of Epoch = 40
# Train loss:= 0.1770 - Val loss: 0.1735 - Test loss: 0.1783 - Train acc:= 94.71% - Val acc:= 95.20% - Test acc:= 94.67%
# Number of Simulation = 7 - Number of Epoch = 45
# Train loss:= 0.1667 - Val loss: 0.1653 - Test loss: 0.1697 - Train acc:= 95.00% - Val acc:= 95.38% - Test acc:= 94.88%
# Number of Simulation = 7 - Number of Epoch = 50
# Train loss:= 0.1578 - Val loss: 0.1586 - Test loss: 0.1625 - Train acc:= 95.30% - Val acc:= 95.57% - Test acc:= 95.15%
#
# Total time taken (in seconds): 337.44
# Number of Simulation = 8 - Number of Epoch = 5
# Train loss:= 0.4355 - Val loss: 0.3922 - Test loss: 0.4060 - Train acc:= 87.66% - Val acc:= 89.37% - Test acc:= 88.59%
# Number of Simulation = 8 - Number of Epoch = 10
# Train loss:= 0.3121 - Val loss: 0.2806 - Test loss: 0.2925 - Train acc:= 90.87% - Val acc:= 91.84% - Test acc:= 91.48%
# Number of Simulation = 8 - Number of Epoch = 15
# Train loss:= 0.2645 - Val loss: 0.2406 - Test loss: 0.2510 - Train acc:= 92.33% - Val acc:= 92.94% - Test acc:= 92.72%
# Number of Simulation = 8 - Number of Epoch = 20
# Train loss:= 0.2355 - Val loss: 0.2166 - Test loss: 0.2256 - Train acc:= 93.17% - Val acc:= 93.60% - Test acc:= 93.38%
# Number of Simulation = 8 - Number of Epoch = 25
# Train loss:= 0.2147 - Val loss: 0.1995 - Test loss: 0.2077 - Train acc:= 93.82% - Val acc:= 94.23% - Test acc:= 93.88%
# Number of Simulation = 8 - Number of Epoch = 30
# Train loss:= 0.1984 - Val loss: 0.1865 - Test loss: 0.1935 - Train acc:= 94.33% - Val acc:= 94.63% - Test acc:= 94.26%
# Number of Simulation = 8 - Number of Epoch = 35
# Train loss:= 0.1849 - Val loss: 0.1757 - Test loss: 0.1816 - Train acc:= 94.66% - Val acc:= 95.09% - Test acc:= 94.68%
# Number of Simulation = 8 - Number of Epoch = 40
# Train loss:= 0.1734 - Val loss: 0.1670 - Test loss: 0.1718 - Train acc:= 94.99% - Val acc:= 95.37% - Test acc:= 94.93%
# Number of Simulation = 8 - Number of Epoch = 45
# Train loss:= 0.1633 - Val loss: 0.1592 - Test loss: 0.1634 - Train acc:= 95.25% - Val acc:= 95.61% - Test acc:= 95.16%
# Number of Simulation = 8 - Number of Epoch = 50
# Train loss:= 0.1544 - Val loss: 0.1529 - Test loss: 0.1561 - Train acc:= 95.49% - Val acc:= 95.78% - Test acc:= 95.32%
#
# Total time taken (in seconds): 336.95
# Number of Simulation = 9 - Number of Epoch = 5
# Train loss:= 0.4355 - Val loss: 0.3925 - Test loss: 0.4093 - Train acc:= 87.80% - Val acc:= 89.32% - Test acc:= 88.81%
# Number of Simulation = 9 - Number of Epoch = 10
# Train loss:= 0.3120 - Val loss: 0.2831 - Test loss: 0.2961 - Train acc:= 90.98% - Val acc:= 92.01% - Test acc:= 91.51%
# Number of Simulation = 9 - Number of Epoch = 15
# Train loss:= 0.2654 - Val loss: 0.2440 - Test loss: 0.2546 - Train acc:= 92.29% - Val acc:= 93.07% - Test acc:= 92.53%
# Number of Simulation = 9 - Number of Epoch = 20
# Train loss:= 0.2365 - Val loss: 0.2201 - Test loss: 0.2288 - Train acc:= 93.18% - Val acc:= 93.72% - Test acc:= 93.29%
# Number of Simulation = 9 - Number of Epoch = 25
# Train loss:= 0.2151 - Val loss: 0.2029 - Test loss: 0.2098 - Train acc:= 93.82% - Val acc:= 94.26% - Test acc:= 93.89%
# Number of Simulation = 9 - Number of Epoch = 30
# Train loss:= 0.1984 - Val loss: 0.1892 - Test loss: 0.1950 - Train acc:= 94.31% - Val acc:= 94.76% - Test acc:= 94.34%
# Number of Simulation = 9 - Number of Epoch = 35
# Train loss:= 0.1842 - Val loss: 0.1777 - Test loss: 0.1825 - Train acc:= 94.69% - Val acc:= 95.12% - Test acc:= 94.61%
# Number of Simulation = 9 - Number of Epoch = 40
# Train loss:= 0.1725 - Val loss: 0.1684 - Test loss: 0.1722 - Train acc:= 94.96% - Val acc:= 95.41% - Test acc:= 94.92%
# Number of Simulation = 9 - Number of Epoch = 45
# Train loss:= 0.1625 - Val loss: 0.1605 - Test loss: 0.1636 - Train acc:= 95.21% - Val acc:= 95.62% - Test acc:= 95.14%
# Number of Simulation = 9 - Number of Epoch = 50
# Train loss:= 0.1534 - Val loss: 0.1535 - Test loss: 0.1561 - Train acc:= 95.50% - Val acc:= 95.79% - Test acc:= 95.32%
#
# Total time taken (in seconds): 289.61
# Number of Simulation = 10 - Number of Epoch = 5
# Train loss:= 0.4250 - Val loss: 0.3844 - Test loss: 0.3989 - Train acc:= 88.06% - Val acc:= 89.62% - Test acc:= 89.01%
# Number of Simulation = 10 - Number of Epoch = 10
# Train loss:= 0.3087 - Val loss: 0.2819 - Test loss: 0.2917 - Train acc:= 91.06% - Val acc:= 91.89% - Test acc:= 91.43%
# Number of Simulation = 10 - Number of Epoch = 15
# Train loss:= 0.2632 - Val loss: 0.2428 - Test loss: 0.2512 - Train acc:= 92.41% - Val acc:= 92.96% - Test acc:= 92.37%
# Number of Simulation = 10 - Number of Epoch = 20
# Train loss:= 0.2350 - Val loss: 0.2185 - Test loss: 0.2267 - Train acc:= 93.24% - Val acc:= 93.58% - Test acc:= 93.11%
# Number of Simulation = 10 - Number of Epoch = 25
# Train loss:= 0.2146 - Val loss: 0.2007 - Test loss: 0.2089 - Train acc:= 93.83% - Val acc:= 94.13% - Test acc:= 93.68%
# Number of Simulation = 10 - Number of Epoch = 30
# Train loss:= 0.1984 - Val loss: 0.1862 - Test loss: 0.1946 - Train acc:= 94.32% - Val acc:= 94.58% - Test acc:= 94.04%
# Number of Simulation = 10 - Number of Epoch = 35
# Train loss:= 0.1850 - Val loss: 0.1745 - Test loss: 0.1829 - Train acc:= 94.72% - Val acc:= 94.95% - Test acc:= 94.43%
# Number of Simulation = 10 - Number of Epoch = 40
# Train loss:= 0.1735 - Val loss: 0.1646 - Test loss: 0.1729 - Train acc:= 95.01% - Val acc:= 95.27% - Test acc:= 94.67%
# Number of Simulation = 10 - Number of Epoch = 45
# Train loss:= 0.1636 - Val loss: 0.1564 - Test loss: 0.1644 - Train acc:= 95.32% - Val acc:= 95.55% - Test acc:= 94.88%
# Number of Simulation = 10 - Number of Epoch = 50
# Train loss:= 0.1548 - Val loss: 0.1492 - Test loss: 0.1569 - Train acc:= 95.56% - Val acc:= 95.81% - Test acc:= 95.18%
#
# Total time taken (in seconds): 280.99

# %%
import matplotlib.pyplot as plt
train_average_loss = np.mean(train_loss_record,0)
train_average_acc = np.mean(train_acc_record,0)
val_average_loss = np.mean(val_loss_record,0)
val_average_acc = np.mean(val_acc_record,0)
test_average_loss = np.mean(test_loss_record,0)
test_average_acc = np.mean(test_acc_record,0)

test_var_acc = np.var(test_acc_record,1)[-1]
x = np.linspace(1,NUM_EPOCHS,len(train_average_loss))

plt.figure()
f, ax = plt.subplots(1,2, sharex = True, sharey = False,figsize=(8,3))
f.suptitle('Report of MLP with l2 for MNIST digits data set')


ax[0].plot(x,train_average_loss,label='train')
ax[0].plot(x,val_average_loss,label='val')
ax[0].plot(x,test_average_loss,label='test')
ax[0].set_yscale('log')
ax[0].set_title('')
ax.flat[0].set(xlabel='Num of epochs', ylabel='Average loss')
ax[0].legend()


ax[1].plot(x,train_average_acc,label='train')
ax[1].plot(x,val_average_acc,label='val')
ax[1].plot(x,test_average_acc,label='test')
ax[1].set_title('')
ax.flat[1].set(xlabel='Num of epochs', ylabel='Average accuray')
ax[1].legend()

print('the final average result: test loss := {:.4f} - test acc := {:.2%} - the std of test acc := {:.4f}'
      .format(test_average_loss[-1], test_average_acc[-1], np.sqrt(test_var_acc)))
f.tight_layout()
plt.show()
# Out:
# the final average result: test loss := 0.1602 - test acc := 95.23% - the std of test acc := 0.0181
